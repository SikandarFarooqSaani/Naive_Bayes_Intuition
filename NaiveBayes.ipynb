# %%
import numpy as np
import pandas as pd
import kagglehub
import os

# %%
path = kagglehub.dataset_download("fredericobreno/play-tennis")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# ...
# 100%|██████████| 337/337 [00:00<00:00, 595kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fredericobreno/play-tennis/versions/1
# ['play_tennis.csv']

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/fredericobreno/play-tennis/versions/1/play_tennis.csv')

# %%
df.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.drop('day', axis=1, inplace=True)

# %%
#Problem is outlook - Sunny , humdidity high , wind weak

# %%
#lookup table is made by neive bayes and stores all the probabilities

# %%
#p(yes)
df['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py = 9/14
pn = 5/14

# %%
#outlook column
pd.crosstab(df['outlook'],df['play']) #prob of play as per outlook

#note down notes
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
pon = 0
prn = 2/5
psn = 3/5
poy = 4/9
pry = 3/9
psy = 2/9

# %%
#temprature
pd.crosstab(df['temp'],df['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pcoolno = 1/5
photno = 2/5
pmildno = 2/5
pcoolyes = 3/9
photyes = 2/9
pmildyes = 4/9

# %%
pd.crosstab(df['humidity'],df['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
phighno = 4/5
pnormalno = 1/5
phighyes = 3/9
pnormalyes = 6/9

# %%
pd.crosstab(df['wind'],df['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
pstrongno = 3/5
pweakno = 2/5
pstrongyes = 3/9
pweakyes = 6/9

# %%
#p(yes|sunny,hot,high,weak) = p(sunny|yes) * p(hot | yes) * p(high | yes) * p(weak|yes)

pyes = py * psy * photyes * phighyes * pweakyes
pyes
# Out:
# 0.007054673721340388

# %%
pno = pn * psn * photno * phighno * pstrongno
pno
# Out:
# 0.04114285714285714
